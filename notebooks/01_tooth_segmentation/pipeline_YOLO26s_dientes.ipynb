# %% [markdown]
# # Trains YOLO26s-seg from scratch on the tooth instance-segmentation dataset (DATASET DIENTES), with targeted oversampling of the '3rd Molar' minority class. Generates article Table 9 (class distribution), Figure 2 (oversampling effect), Figure 3 (augmentation examples), and contributes one row to the cross-variant comparison table used for Table 10/11.

# %% [markdown]
# ## CELL 1 — Set up the unit and copy the dataset into Colab

# %%
import os, shutil
from pathlib import Path
from google.colab import drive

drive.mount('/content/drive')

src = Path("/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/DATASET DIENTES")
dst = Path("/content/dataset")

if not dst.exists():
    print("Copiando dataset...")
    shutil.copytree(src, dst)
    print("✅ Copia completada")
# Out:
# Mounted at /content/drive
# Copiando dataset...
# ✅ Copia completada

# %% [markdown]
# ## CELL 2 — Verify the dataset

# %%
splits = ['train', 'valid', 'test']
for split in splits:
    imgs = list((dst / split / 'images').glob('*'))
    lbls = list((dst / split / 'labels').glob('*.txt'))
    print(f"{split}: {len(imgs)} imágenes | {len(lbls)} labels")
# Out:
# train: 1650 imágenes | 1750 labels
# valid: 110 imágenes | 110 labels
# test: 73 imágenes | 73 labels

# %% [markdown]
# ## CELL 3 — Identify Classes

# %%
import glob

ids = set()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line in open(f):
        if line.strip():
            ids.add(int(line.split()[0]))

print(f"Total de clases: {len(ids)}")
print(f"IDs encontrados: {sorted(ids)}")
# Out:
# Total de clases: 8
# IDs encontrados: [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ## CELL 4 — Configure data.yaml

# %%
yaml_content = """names:
- 1st Molar
- 1st Premolar
- 2nd Molar
- 2nd Premolar
- 3rd Molar
- Canine
- Central Incisor
- Lateral Incisor
nc: 8
path: /content/dataset
test: test/images
train: train/images
val: valid/images
"""

with open('/content/dataset/data.yaml', 'w') as f:
    f.write(yaml_content)
print("✅ data.yaml actualizado")

names = ['1st Molar', '1st Premolar', '2nd Molar', '2nd Premolar',
         '3rd Molar', 'Canine', 'Central Incisor', 'Lateral Incisor']
# Out:
# ✅ data.yaml actualizado

# %%
from collections import Counter
import glob

labels = glob.glob('/content/dataset/train/labels/*.txt')
counter = Counter()
for f in labels:
    with open(f) as file:
        for line in file:
            class_id = line.split()[0]
            counter[class_id] += 1
print(counter)
# Out:
# Counter({'6': 4603, '7': 4491, '5': 4417, '1': 4093, '0': 3587, '3': 3576, '2': 2775, '4': 491})

# %% [markdown]
# ## CELL 5 — Install the YOLO library

# %%
# ⚠️ After running: Runtime Menu > Restart Session
# !pip install ultralytics albumentations
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.92-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.13.4)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.92-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.92 ultralytics-thop-2.0.20

# %% [markdown]
# ## CELL 5.5 — Oversampling with augmentation while preserving SEGMENTATION (polygons)
#
# Just like in the nano pipeline: the minority class (3rd Molar) is balanced by generating augmented copies while preserving the polygons.

# %%
import cv2
import numpy as np
import glob, os
import albumentations as A

transform = A.Compose([
    A.Rotate(limit=15, p=0.7),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.6),
    A.Affine(scale=(0.9, 1.1), p=0.5),
    A.GaussNoise(std_range=(0.02, 0.08), p=0.3),
], keypoint_params=A.KeypointParams(format='xy', remove_invisible=False))

labels_con_3er_molar = [f for f in glob.glob('/content/dataset/train/labels/*.txt')
                         if any(line.startswith('4 ') for line in open(f))]

print(f"Imágenes con 3rd Molar: {len(labels_con_3er_molar)}")

N_COPIAS = 5

for label_path in labels_con_3er_molar:
    img_path = label_path.replace('labels', 'images').replace('.txt', '.jpg')
    if not os.path.exists(img_path):
        continue
    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    poligonos = []
    clases = []
    with open(label_path) as f:
        for line_str in f:
            parts = line_str.strip().split()
            if not parts:
                continue
            cls_id = int(parts[0])
            coords = [float(p) for p in parts[1:]]
            puntos_norm = np.array(coords).reshape(-1, 2)
            puntos_px = puntos_norm * [w, h]
            poligonos.append(puntos_px)
            clases.append(cls_id)

    todos_los_puntos = np.vstack(poligonos)
    longitudes = [len(p) for p in poligonos]

    for i in range(N_COPIAS):
        try:
            aug = transform(image=img, keypoints=todos_los_puntos.tolist())
        except Exception as e:
            print(f"⚠️ Error en {img_path}: {e}")
            continue

        img_aug = aug['image']
        kpts_aug = np.array(aug['keypoints'])
        h_new, w_new = img_aug.shape[:2]

        nuevos_poligonos = []
        idx = 0
        for longitud in longitudes:
            poly = kpts_aug[idx:idx+longitud]
            idx += longitud
            poly_norm = poly / [w_new, h_new]
            poly_norm = np.clip(poly_norm, 0, 1)
            nuevos_poligonos.append(poly_norm)

        nuevo_nombre = os.path.basename(img_path).replace('.jpg', f'_aug3M_{i}.jpg')
        nueva_img_path = img_path.replace(os.path.basename(img_path), nuevo_nombre)
        nueva_label_path = nueva_img_path.replace('images', 'labels').replace('.jpg', '.txt')

        cv2.imwrite(nueva_img_path, img_aug)
        with open(nueva_label_path, 'w') as f:
            for cls, poly in zip(clases, nuevos_poligonos):
                coords_str = ' '.join(f"{x:.6f} {y:.6f}" for x, y in poly)
                f.write(f"{cls} {coords_str}\n")

print("✅ Oversampling con segmentación preservada — dataset balanceado listo")

ids = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line_str in open(f):
        if line_str.strip():
            ids[int(line_str.split()[0])] += 1
print(ids)
# Out:
# Imágenes con 3rd Molar: 338
# ✅ Oversampling con segmentación preservada — dataset balanceado listo
# Counter({6: 8308, 7: 8156, 5: 8042, 1: 7368, 0: 6852, 3: 6151, 2: 5975, 4: 2856})

# %% [markdown]
# ## CELL A — Comparative Chart of Class Distribution (for the article)

# %%
import matplotlib.pyplot as plt
from collections import Counter
import glob

conteo_antes = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    if '_aug3M_' in f:
        continue
    for line in open(f):
        if line.strip():
            conteo_antes[int(line.split()[0])] += 1

conteo_despues = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line in open(f):
        if line.strip():
            conteo_despues[int(line.split()[0])] += 1

x = range(8)
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar([i - 0.2 for i in x], [conteo_antes.get(i, 0) for i in x], width=0.4, label='Antes', color='#94a3b8')
ax.bar([i + 0.2 for i in x], [conteo_despues.get(i, 0) for i in x], width=0.4, label='Después', color='#3b82f6')
ax.set_xticks(x)
ax.set_xticklabels(names, rotation=30, ha='right')
ax.set_ylabel('Número de instancias')
ax.set_title('Distribución de clases antes y después del oversampling')
ax.legend()
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/distribucion_clases.png', dpi=200)
plt.show()

print(f"3rd Molar — Antes: {conteo_antes.get(4,0)} | Después: {conteo_despues.get(4,0)}")
# Out:
# 3rd Molar — Antes: 491 | Después: 2856

# %% [markdown]
# ## CELL B — View original image vs. enlarged versions with masks

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def dibujar_poligonos(img_path, label_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w = img.shape[:2]
    overlay = img.copy()

    colores = {0:(255,99,71), 1:(60,179,113), 2:(65,105,225), 3:(255,215,0),
               4:(255,20,147), 5:(148,0,211), 6:(0,206,209), 7:(255,140,0)}

    with open(label_path) as f:
        for line in f:
            parts = line.split()
            cls = int(parts[0])
            coords = np.array(list(map(float, parts[1:]))).reshape(-1, 2)
            coords[:, 0] *= w
            coords[:, 1] *= h
            pts = coords.astype(np.int32)
            cv2.fillPoly(overlay, [pts], colores.get(cls, (200,200,200)))

    return cv2.addWeighted(img, 0.6, overlay, 0.4, 0)

ejemplo_original = labels_con_3er_molar[0]
img_original_path = ejemplo_original.replace('labels', 'images').replace('.txt', '.jpg')

base_name = os.path.basename(img_original_path).replace('.jpg', '')
versiones_aug = [
    f'/content/dataset/train/images/{base_name}_aug3M_0.jpg',
    f'/content/dataset/train/images/{base_name}_aug3M_1.jpg',
]

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

img_orig = dibujar_poligonos(img_original_path, ejemplo_original)
axes[0].imshow(img_orig)
axes[0].set_title('(a) Imagen original')
axes[0].axis('off')

for i, ruta_aug in enumerate(versiones_aug):
    label_aug = ruta_aug.replace('images', 'labels').replace('.jpg', '.txt')
    if os.path.exists(ruta_aug):
        img_aug = dibujar_poligonos(ruta_aug, label_aug)
        axes[i+1].imshow(img_aug)
        axes[i+1].set_title(f'({chr(98+i)}) Versión aumentada {i+1}')
        axes[i+1].axis('off')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_augmentation.png', dpi=200)
plt.show()

# %% [markdown]
# ## CELL 6 — Training from Scratch | YOLO26m-seg with a Balanced Dataset

# %%
from ultralytics import YOLO

model = YOLO('yolo26s-seg.yaml')

results = model.train(
    data='/content/dataset/data.yaml',
    epochs=150,
    imgsz=640,
    batch=8,
    pretrained=False,
    project='runs/dientes',
    name='yolo26s_dientes',
    patience=30,
    device='cuda:0',

    optimizer='AdamW',
    lr0=0.001,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,

    fliplr=0.5,
    flipud=0.1,
    mosaic=1.0,
    mixup=0.1,
    degrees=10.0,
    translate=0.1,
    scale=0.5,
    shear=2.0,

    cos_lr=True,
    close_mosaic=15,
    val=True,
    verbose=True
)

# Get the actual save directory from the results object (avoids path mismatches between the requested 'name' and Ultralytics' actual save folder).
SAVE_DIR = results.save_dir
BEST_MODEL_PATH = SAVE_DIR / 'weights' / 'best.pt'
print(f"📁 Carpeta de resultados: {SAVE_DIR}")
print(f"🏆 Mejor modelo: {BEST_MODEL_PATH}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=15, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/dataset/data.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.1, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolo26s-seg.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26s_dientes, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=runs/dientes, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/segment/runs/dientes/yolo26s_dientes, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2424784  ultralytics.nn.modules.head.Segment26        [8, 32, 128, 1, True, [128, 256, 512]]
# YOLO26s-seg summary: 309 layers, 11,440,784 parameters, 11,440,784 gradients, 37.1 GFLOPs
#
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 101.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2016.9±1903.0 MB/s, size: 1300.7 KB)
# train: Scanning /content/dataset/train/labels... 3265 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3265/3265 517.5it/s 6.3s
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 65.1±33.6 MB/s, size: 496.5 KB)
# val: Scanning /content/dataset/valid/labels... 110 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 110/110 164.1it/s 0.7s
# val: New cache created: /content/dataset/valid/labels.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 134 weight(decay=0.0), 154 weight(decay=0.0005), 154 bias(decay=0.0)
# Plotting labels to /content/runs/segment/runs/dientes/yolo26s_dientes/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/segment/runs/dientes/yolo26s_dientes
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/150      4.72G      1.886      3.571      2.982    0.01099      3.171         13        640: 100% ━━━━━━━━━━━━ 409/409 1.1s/it 7:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.0s/it 20.9s
#                    all        110       1741      0.368      0.461      0.364      0.217      0.367      0.464      0.365      0.188
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/150      5.63G      1.416      2.514      1.867   0.007579      2.148         38        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.2s
#                    all        110       1741       0.53      0.575      0.567      0.415      0.555      0.554      0.567      0.408
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3/150      5.64G      1.245      1.965       1.52    0.00649      1.644         24        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.4s
#                    all        110       1741      0.621      0.623      0.665      0.499      0.621      0.623      0.664       0.52
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       4/150      5.64G      1.162      1.694      1.325   0.005934      1.315         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.1s
#                    all        110       1741      0.747      0.656      0.759      0.576      0.737      0.666      0.759      0.611
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       5/150      5.64G      1.098      1.563        1.2   0.005536      1.161         72        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741      0.751      0.701      0.804      0.647      0.752      0.701      0.802      0.662
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       6/150      5.64G       1.03      1.417      1.089   0.005132      1.046         21        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.6s
#                    all        110       1741      0.809      0.708      0.829      0.677       0.81      0.711       0.83      0.704
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       7/150      5.64G     0.9907      1.389      1.037   0.004902      1.004         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.9s
#                    all        110       1741      0.855      0.726      0.852      0.685      0.856      0.728      0.851      0.714
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       8/150      5.64G     0.9748       1.33     0.9791   0.004773     0.9288         50        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.5s
#                    all        110       1741      0.801      0.785      0.863      0.701      0.801      0.787      0.864      0.742
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       9/150      5.64G     0.9291      1.266     0.9242    0.00458     0.8793         12        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.3s
#                    all        110       1741      0.826      0.788      0.895      0.745       0.83      0.787      0.895      0.766
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      10/150      5.64G     0.8991      1.197     0.8633   0.004334     0.8253         24        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741      0.891      0.801      0.919      0.776       0.89      0.803      0.922      0.799
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      11/150      5.64G     0.8891       1.19     0.8507   0.004303     0.8302         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741      0.883        0.8      0.907      0.766      0.864      0.813      0.907      0.784
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      12/150      5.64G      0.864      1.146     0.8015   0.004195     0.7653         35        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.9s
#                    all        110       1741      0.872      0.801      0.914      0.782       0.89       0.79      0.913      0.799
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      13/150      5.64G     0.8346      1.119     0.7827   0.004022     0.7249         32        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.4s
#                    all        110       1741      0.883      0.841      0.923      0.795      0.883       0.84      0.923      0.807
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      14/150      5.64G      0.823      1.125     0.7715   0.003979     0.7205         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.879      0.846      0.932        0.8      0.878      0.847      0.932      0.811
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      15/150      5.64G     0.8109      1.099      0.746   0.003905     0.6981         22        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.3s
#                    all        110       1741      0.889      0.858      0.932      0.806       0.89      0.859      0.932      0.814
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      16/150      5.64G     0.7772      1.031     0.6949   0.003719     0.6398         34        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.861      0.878      0.929        0.8      0.863       0.88      0.931      0.813
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      17/150      5.64G     0.7804      1.062     0.6981   0.003747     0.6565         80        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.5s
#                    all        110       1741      0.862      0.826      0.923        0.8      0.862      0.826      0.924      0.818
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      18/150      5.64G     0.7652       1.02     0.6722   0.003645     0.6283         12        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.899      0.854      0.937      0.813        0.9      0.854      0.936       0.82
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      19/150      5.64G     0.7637      1.024      0.677    0.00358     0.6384         64        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741      0.851       0.87      0.924      0.803      0.851      0.864      0.924      0.821
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      20/150      5.64G     0.7646      1.034     0.6684   0.003604     0.6311         13        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741      0.858      0.869      0.929      0.807      0.857      0.869       0.93       0.81
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      21/150      5.64G     0.7363     0.9898     0.6477   0.003486     0.6207         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s
#                    all        110       1741      0.867      0.898      0.941      0.815      0.868      0.899      0.941      0.826
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      22/150      5.64G     0.7407     0.9916     0.6372   0.003459     0.6031         42        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.8s
#                    all        110       1741      0.893      0.869      0.936      0.821      0.894       0.87      0.937      0.823
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      23/150      5.64G     0.7194     0.9835     0.6333   0.003412     0.6082         13        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.0s
#                    all        110       1741      0.863      0.882      0.939      0.814      0.862      0.881      0.939      0.825
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      24/150      5.64G     0.7288     0.9769     0.6258   0.003434     0.5853         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.934      0.868      0.946      0.832      0.934      0.869      0.946      0.838
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      25/150      5.64G     0.7192     0.9736     0.6137   0.003367     0.5688         32        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.5s
#                    all        110       1741      0.872      0.883      0.935      0.821      0.873      0.883      0.935      0.823
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      26/150      5.64G     0.7135     0.9585     0.5929   0.003311     0.5508         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.3s
#                    all        110       1741      0.918      0.882      0.954      0.838       0.92      0.882      0.952       0.84
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      27/150      5.64G     0.6971     0.9305      0.587   0.003234     0.5491         31        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.7s
#                    all        110       1741      0.911      0.855      0.947      0.839       0.88       0.89      0.948      0.842
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      28/150      5.64G     0.7042     0.9532     0.5892   0.003274     0.5427         31        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.903      0.906       0.95      0.838      0.904      0.905      0.951      0.838
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      29/150      5.64G     0.6887     0.9147     0.5645   0.003161     0.5196         16        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.8s
#                    all        110       1741      0.902      0.868      0.939      0.834      0.902      0.867      0.939      0.831
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      30/150      5.64G      0.677     0.9005     0.5567    0.00313     0.5176         37        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 7.0s
#                    all        110       1741      0.928      0.883      0.952      0.844      0.929      0.884      0.954      0.841
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      31/150      5.64G     0.6844     0.9334      0.569   0.003166     0.5305         24        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s
#                    all        110       1741        0.9      0.899       0.96      0.853      0.901      0.899       0.96      0.852
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      32/150      5.64G     0.6844     0.9247     0.5544   0.003161      0.508         23        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.2s
#                    all        110       1741      0.881      0.919      0.957       0.85      0.882      0.914      0.958      0.842
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      33/150      5.64G     0.6738     0.9034     0.5516   0.003114     0.5165         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.924      0.886      0.958      0.856      0.925      0.887      0.958      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      34/150      5.64G     0.6742     0.9099     0.5394     0.0031     0.4907         68        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741       0.93        0.9      0.961      0.855       0.93        0.9      0.962      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      35/150      5.64G      0.669     0.8974     0.5404   0.003099     0.5024         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.932      0.892      0.964      0.865      0.932      0.893      0.965      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      36/150      5.64G     0.6583     0.8841     0.5276   0.003039     0.4866         29        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.911      0.906      0.964      0.867      0.913      0.907      0.965      0.857
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      37/150      5.64G     0.6623     0.8944     0.5347   0.003093     0.4892         79        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741      0.918      0.899      0.963      0.859      0.918        0.9      0.963      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      38/150      5.64G     0.6546     0.8745     0.5205   0.002986     0.4833         54        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.0s
#                    all        110       1741      0.926      0.885      0.952      0.856      0.927      0.886      0.953      0.842
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      39/150      5.64G     0.6546     0.8832     0.5277   0.003023     0.4894         51        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.2s
#                    all        110       1741      0.939      0.888      0.958      0.859       0.94      0.889      0.959      0.849
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      40/150      5.64G     0.6598     0.8802     0.5211   0.003012     0.4791         22        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.7s
#                    all        110       1741      0.929      0.889      0.954      0.857       0.93       0.89      0.955       0.85
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      41/150      5.64G     0.6429     0.8651     0.5145   0.002971     0.4779         32        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s
#                    all        110       1741      0.924      0.882       0.96      0.859      0.925      0.883      0.962      0.849
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      42/150      5.64G     0.6385     0.8551     0.5108   0.002958     0.4733         30        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.2s
#                    all        110       1741      0.914      0.921      0.959      0.854      0.915      0.919      0.958      0.858
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      43/150      5.64G     0.6327      0.853     0.4932   0.002895     0.4527         17        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.3s
#                    all        110       1741      0.903      0.921      0.965      0.865      0.904      0.921      0.964      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      44/150      5.64G     0.6288     0.8409     0.4884   0.002856     0.4426         28        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.3s
#                    all        110       1741      0.922      0.901       0.96      0.865      0.922        0.9       0.96      0.851
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      45/150      5.64G     0.6395     0.8545     0.4859   0.002894     0.4318         15        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.2s
#                    all        110       1741      0.925      0.898      0.957      0.864      0.926      0.899      0.957      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      46/150      5.64G     0.6225     0.8316     0.4842   0.002822     0.4386         58        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1s/it 7.6s
#                    all        110       1741      0.914      0.888      0.958      0.862      0.914      0.887      0.958      0.858
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      47/150      5.64G     0.6387     0.8596     0.4947   0.002903     0.4382         24        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.8s
#                    all        110       1741      0.921      0.902      0.962       0.87      0.921      0.903      0.962      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      48/150      5.64G     0.6243     0.8347     0.4823   0.002834     0.4355         81        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.4s
#                    all        110       1741      0.939       0.88      0.964      0.873      0.939       0.88      0.963      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      49/150      5.64G     0.6172     0.8249     0.4705   0.002824     0.4201         28        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.7s
#                    all        110       1741      0.924      0.908       0.96      0.866      0.924      0.909       0.96      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      50/150      5.64G     0.6215     0.8377     0.4784   0.002825     0.4296         40        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 7.0s
#                    all        110       1741       0.92      0.903      0.956       0.86      0.921      0.904      0.956      0.854
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      51/150      5.64G     0.6223     0.8393     0.4764   0.002855     0.4224         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.2s
#                    all        110       1741      0.937       0.89      0.954      0.864      0.938       0.89      0.954      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      52/150      5.64G     0.6183     0.8405     0.4757   0.002852     0.4308         31        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.7s
#                    all        110       1741      0.917      0.893       0.95      0.861      0.917      0.894       0.95      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      53/150      5.64G     0.6074      0.817     0.4622   0.002801     0.4078         23        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.929      0.902      0.967      0.878      0.929      0.903      0.967      0.865
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      54/150      5.64G     0.6097     0.8178     0.4602   0.002789     0.4118         27        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.5s
#                    all        110       1741      0.936      0.898      0.961       0.87      0.936      0.898       0.96      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      55/150      5.64G     0.6072     0.8244     0.4613   0.002782     0.4158         22        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741      0.944      0.897      0.969      0.873      0.944      0.897      0.969      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      56/150      5.64G     0.5953      0.795     0.4377   0.002707     0.3923         47        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 6.0s
#                    all        110       1741      0.892      0.927      0.959      0.862      0.892      0.927       0.96      0.857
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      57/150      5.64G     0.5917     0.7895     0.4444    0.00269     0.3994         28        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.8s
#                    all        110       1741      0.918      0.918      0.963      0.875      0.919      0.919      0.963      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      58/150      5.64G     0.5906     0.7886     0.4301   0.002696     0.3811         10        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s
#                    all        110       1741      0.925      0.926      0.969      0.879      0.925      0.926      0.969      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      59/150      5.64G     0.5955     0.8163     0.4454   0.002687     0.4089         40        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.2s
#                    all        110       1741      0.889      0.921      0.959      0.868      0.889      0.921      0.959      0.854
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      60/150      5.64G     0.5885     0.7875     0.4333   0.002635     0.3852         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.4s
#                    all        110       1741      0.936      0.903      0.967      0.876      0.936      0.903      0.967      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      61/150      5.64G     0.5934     0.8018     0.4366   0.002658     0.3839         23        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.8s
#                    all        110       1741      0.922      0.911      0.957      0.864      0.923      0.911      0.957      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      62/150      5.64G      0.585     0.7881     0.4304   0.002664     0.3803         16        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s
#                    all        110       1741      0.916      0.908      0.954      0.867      0.916      0.908      0.954      0.852
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      63/150      5.64G     0.5849     0.7851     0.4302   0.002641     0.3728         13        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.4s
#                    all        110       1741      0.927      0.916      0.962      0.879      0.927      0.916      0.963      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      64/150      5.64G     0.5857     0.7779     0.4183   0.002669     0.3678         12        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6it/s 4.5s
#                    all        110       1741      0.923      0.916      0.964      0.874      0.923      0.919      0.964      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      65/150      5.64G      0.591     0.7843     0.4184   0.002692     0.3573         27        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s
#                    all        110       1741      0.936      0.905      0.959      0.873      0.936      0.905      0.959      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      66/150      5.64G     0.5753      0.764     0.4165    0.00262      0.369         26        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.3s
#                    all        110       1741      0.903       0.89      0.946      0.861      0.903       0.89      0.947      0.848
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      67/150      5.64G     0.5765     0.7785     0.4162   0.002593     0.3583         72        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s
#                    all        110       1741      0.907      0.902       0.96      0.876      0.907      0.902       0.96      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      68/150      5.64G     0.5739     0.7772     0.4202    0.00257     0.3627         14        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.9s
#                    all        110       1741      0.902      0.919      0.955      0.874      0.903       0.92      0.958      0.857
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      69/150      5.64G     0.5683     0.7684     0.4126   0.002567     0.3602         39        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.0s
#                    all        110       1741      0.929      0.908      0.966      0.882      0.929      0.909      0.967      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      70/150      5.64G     0.5715     0.7645     0.4101   0.002566     0.3699         26        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s
#                    all        110       1741      0.924      0.911      0.958      0.875      0.924      0.911      0.958      0.864
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      71/150      5.64G     0.5657     0.7565       0.41   0.002574      0.361         17        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.0s
#                    all        110       1741      0.941       0.91      0.958      0.873      0.938      0.911      0.959       0.86
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      72/150      5.64G     0.5793      0.784     0.4194   0.002579     0.3611         37        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s
#                    all        110       1741      0.926      0.911      0.963       0.88      0.926      0.911      0.966      0.872
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      73/150      5.64G     0.5776     0.7824     0.4196   0.002609     0.3629         12        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:10
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741      0.924      0.934      0.966      0.882      0.924      0.934      0.966       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      74/150      5.64G     0.5619     0.7461     0.3907   0.002507     0.3372         35        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.6s
#                    all        110       1741       0.92      0.935      0.965      0.879      0.921      0.935      0.965      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      75/150      5.64G     0.5655     0.7606     0.3975   0.002562     0.3409         29        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.7s
#                    all        110       1741      0.936      0.923      0.976       0.89      0.937      0.923      0.976      0.876
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      76/150      5.64G     0.5602     0.7569     0.3958   0.002551     0.3446         12        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.1s
#                    all        110       1741      0.946      0.904      0.963      0.881      0.946      0.904      0.964      0.869
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
# ...
#                    all        110       1741       0.93      0.946      0.968      0.892       0.93      0.945      0.968      0.873
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     113/150      5.64G     0.5137      0.699     0.3325   0.002293     0.2719         60        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s
#                    all        110       1741      0.926      0.942      0.969      0.892      0.925      0.941      0.969      0.874
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     114/150      5.64G      0.512     0.6949     0.3339   0.002297     0.2752         54        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s
#                    all        110       1741      0.932      0.925      0.969      0.892      0.932      0.925      0.969      0.873
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     115/150      5.64G     0.5144     0.6963     0.3318   0.002283     0.2643         20        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741       0.92      0.926      0.965      0.888      0.922      0.923      0.965      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     116/150      5.64G     0.5143     0.7026     0.3351     0.0023     0.2697         33        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.929      0.912      0.965      0.891       0.93      0.911      0.965      0.871
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     117/150      5.64G     0.5056     0.6845     0.3211   0.002264     0.2607         42        640: 100% ━━━━━━━━━━━━ 409/409 1.2it/s 5:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.2s
#                    all        110       1741      0.927      0.916      0.965      0.888      0.937      0.909      0.965       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     118/150      5.64G     0.5051     0.6859     0.3233   0.002208     0.2638         28        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.9s
#                    all        110       1741      0.938      0.922      0.969      0.891      0.938      0.922      0.969      0.874
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     119/150      5.64G     0.5026     0.6784     0.3193   0.002238     0.2522         23        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.3s
#                    all        110       1741      0.935      0.919      0.969      0.891      0.936      0.919       0.97      0.873
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     120/150      5.64G     0.5064     0.6804     0.3199   0.002218     0.2593         23        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.0s
#                    all        110       1741       0.94      0.906      0.959      0.886      0.941      0.906      0.959      0.865
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     121/150      5.64G     0.4969     0.6677     0.3128   0.002205     0.2445         33        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 4.9s
#                    all        110       1741      0.934      0.917      0.967      0.889      0.933      0.916      0.967      0.871
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     122/150      5.64G     0.5091     0.6867     0.3244    0.00225     0.2596         21        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9it/s 3.8s
#                    all        110       1741      0.941      0.913      0.966      0.888      0.941      0.912      0.966       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     123/150      5.64G     0.5021     0.6759     0.3185   0.002205     0.2545         26        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741       0.93       0.91      0.965      0.888      0.939      0.898      0.965       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     124/150      5.64G     0.5059     0.6843     0.3203    0.00224     0.2625         55        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.7s
#                    all        110       1741      0.934      0.909      0.961      0.887      0.934      0.909      0.961      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     125/150      5.64G     0.5044     0.6835      0.316   0.002206     0.2527         80        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 6.0s
#                    all        110       1741      0.926      0.915      0.963      0.886      0.925      0.914      0.963      0.869
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     126/150      5.64G     0.4969     0.6701     0.3114   0.002193     0.2535         33        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s
#                    all        110       1741      0.923       0.93      0.964      0.888      0.923       0.93      0.964       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     127/150      5.64G     0.5044     0.6847     0.3222   0.002222     0.2557         16        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.9s
#                    all        110       1741      0.938      0.912      0.963      0.886      0.937      0.911      0.963      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     128/150      5.64G     0.5016     0.6782     0.3183   0.002207     0.2545         47        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        110       1741      0.934      0.913      0.967       0.89      0.934      0.912      0.966      0.873
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     129/150      5.64G     0.5012     0.6763     0.3187   0.002204     0.2562         36        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.7s
#                    all        110       1741      0.923      0.927      0.964      0.889      0.922      0.926      0.964       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     130/150      5.64G     0.5027     0.6811     0.3149   0.002208     0.2544         51        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s
#                    all        110       1741      0.927      0.911      0.965      0.889      0.927      0.911      0.965       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     131/150      5.64G     0.4988     0.6748     0.3139   0.002211     0.2495         74        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s
#                    all        110       1741      0.926      0.921      0.966       0.89      0.926      0.921      0.966      0.872
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     132/150      5.64G     0.5048     0.6801     0.3212   0.002217      0.258         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.8s
#                    all        110       1741      0.934      0.903      0.964      0.888      0.939      0.898      0.964      0.869
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     133/150      5.64G     0.5014     0.6839     0.3142   0.002191     0.2522         18        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.4s
#                    all        110       1741      0.939      0.897      0.961      0.885      0.939      0.896      0.961      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     134/150      5.64G     0.4967     0.6687     0.3116   0.002191     0.2506         37        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 5:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.5it/s 4.6s
#                    all        110       1741      0.909       0.93      0.964      0.888      0.908       0.93      0.964      0.871
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     135/150      5.64G      0.505     0.6896     0.3222    0.00222     0.2531         27        640: 100% ━━━━━━━━━━━━ 409/409 1.1it/s 6:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.4s
#                    all        110       1741      0.916      0.923      0.964      0.888      0.915      0.923      0.964      0.871
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     136/150      5.64G     0.3884     0.4871     0.1823   0.001961     0.1435         16        640: 100% ━━━━━━━━━━━━ 409/409 1.7it/s 4:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.0s
#                    all        110       1741      0.946      0.898       0.96      0.882      0.948      0.896       0.96      0.863
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 106, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 136 epochs completed in 14.201 hours.
# Optimizer stripped from /content/runs/segment/runs/dientes/yolo26s_dientes/weights/last.pt, 23.4MB
# Optimizer stripped from /content/runs/segment/runs/dientes/yolo26s_dientes/weights/best.pt, 23.4MB
#
# Validating /content/runs/segment/runs/dientes/yolo26s_dientes/weights/best.pt...
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-seg summary (fused): 139 layers, 10,368,436 parameters, 0 gradients, 34.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.6s/it 11.5s
#                    all        110       1741      0.938      0.933      0.974      0.897      0.956      0.916      0.974      0.879
#              1st Molar        100        219      0.953      0.925      0.984      0.902      0.985      0.888      0.985      0.902
#           1st Premolar        106        248      0.948      0.957      0.979      0.914      0.963      0.945      0.982      0.896
#              2nd Molar         86        170      0.936       0.95      0.988       0.91      0.955      0.935      0.987      0.906
#           2nd Premolar        102        232      0.964      0.931      0.976      0.902       0.98      0.897      0.975       0.88
#              3rd Molar         13         20      0.829       0.85      0.912      0.777      0.855       0.85      0.912      0.755
#                 Canine        109        282      0.961      0.936      0.987      0.924      0.971      0.922      0.986        0.9
#        Central Incisor        108        287      0.959       0.97      0.982      0.932      0.965       0.96      0.982      0.908
#        Lateral Incisor        109        283      0.957      0.949      0.984      0.914      0.974      0.934      0.984      0.888
# Speed: 1.8ms preprocess, 16.3ms inference, 0.0ms loss, 11.4ms postprocess per image
# Results saved to /content/runs/segment/runs/dientes/yolo26s_dientes
# 📁 Carpeta de resultados: /content/runs/segment/runs/dientes/yolo26s_dientes
# 🏆 Mejor modelo: /content/runs/segment/runs/dientes/yolo26s_dientes/weights/best.pt

# %% [markdown]
# ## CELL C — Training curves (loss, mAP50, precision, recall by epoch)

# %%
import pandas as pd
import matplotlib.pyplot as plt

results_csv = SAVE_DIR / 'results.csv'
df = pd.read_csv(results_csv)
df.columns = df.columns.str.strip()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(df['epoch'], df['train/box_loss'], label='Train box loss')
axes[0].plot(df['epoch'], df['val/box_loss'], label='Val box loss')
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Pérdida')
axes[0].set_title('Curva de pérdida durante el entrenamiento')
axes[0].legend()

axes[1].plot(df['epoch'], df['metrics/mAP50(B)'], label='mAP@50', color='green')
axes[1].plot(df['epoch'], df['metrics/precision(B)'], label='Precisión', color='blue')
axes[1].plot(df['epoch'], df['metrics/recall(B)'], label='Recall', color='orange')
axes[1].axhline(y=0.75, color='red', linestyle='--', label='Meta mAP50 (0.75)')
axes[1].set_xlabel('Época')
axes[1].set_ylabel('Valor')
axes[1].set_title('Métricas de evaluación por época')
axes[1].legend()

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/curvas_entrenamiento_s.png', dpi=200)
plt.show()

# %% [markdown]
# ## CELL D — Metrics by class (table for the article)

# %%
model = YOLO(BEST_MODEL_PATH)
metrics = model.val(data='/content/dataset/data.yaml', split='test')

print("📊 mAP50 por clase:\n")
tabla_resultados = []
for i, name in enumerate(names):
    ap50 = metrics.box.ap50[i] if i < len(metrics.box.ap50) else 0
    tabla_resultados.append({'Clase': name, 'mAP50': f"{ap50:.3f}"})
    print(f"  {name:20s}: {ap50:.3f}")

import pandas as pd
df_resultados = pd.DataFrame(tabla_resultados)
df_resultados.to_csv('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/mAP_por_clase_s.csv', index=False)
print("\n✅ Tabla guardada en Drive para pegar en el artículo")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-seg summary (fused): 139 layers, 10,368,436 parameters, 0 gradients, 34.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 150.6±71.9 MB/s, size: 909.8 KB)
# val: Scanning /content/dataset/test/labels... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 342.7it/s 0.2s
# val: New cache created: /content/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.3s/it 11.6s
#                    all         73       1152      0.917      0.926      0.966       0.89      0.917      0.926       0.96      0.856
#              1st Molar         63        139      0.912      0.898      0.964      0.877      0.912      0.898      0.964      0.872
#           1st Premolar         73        174        0.9      0.914      0.958      0.887        0.9      0.914      0.958      0.866
#              2nd Molar         51        104      0.929      0.894       0.97       0.88      0.929      0.894      0.966      0.881
#           2nd Premolar         64        150      0.902      0.921       0.95      0.864      0.902      0.921       0.95      0.828
#              3rd Molar          9         13      0.854      0.898      0.933       0.84      0.854      0.898      0.888       0.72
#                 Canine         73        190      0.942      0.963      0.982      0.907      0.942      0.963       0.98      0.885
#        Central Incisor         71        190      0.957      0.974      0.989      0.947      0.957      0.974      0.989      0.913
#        Lateral Incisor         73        192      0.938      0.948      0.984      0.919      0.938      0.948      0.984      0.882
# Speed: 5.5ms preprocess, 46.2ms inference, 0.0ms loss, 9.0ms postprocess per image
# Results saved to /content/runs/segment/val
# 📊 mAP50 por clase:
#
#   1st Molar           : 0.964
#   1st Premolar        : 0.958
#   2nd Molar           : 0.970
#   2nd Premolar        : 0.950
#   3rd Molar           : 0.933
#   Canine              : 0.982
#   Central Incisor     : 0.989
#   Lateral Incisor     : 0.984
#
# ✅ Tabla guardada en Drive para pegar en el artículo

# %% [markdown]
# ## CELL 7 — Final evaluation of the test set

# %%
metrics = model.val(
    data='/content/dataset/data.yaml',
    split='test'
)

print("\n📊 RESULTADOS EN TEST:")
print(f"  mAP@50:     {metrics.box.map50:.4f}  (meta: ≥ 0.75)")
print(f"  mAP@50-95:  {metrics.box.map:.4f}")
print(f"  Precisión:  {metrics.box.mp:.4f}   (meta: ≥ 0.80)")
print(f"  Recall:     {metrics.box.mr:.4f}   (meta: ≥ 0.70)")

if metrics.box.map50 >= 0.75:
    print("\n✅ META mAP@50 CUMPLIDA")
else:
    print(f"\n⚠️ mAP@50 = {metrics.box.map50:.4f} — debajo de la meta")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2576.9±1069.5 MB/s, size: 1284.5 KB)
# val: Scanning /content/dataset/test/labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 23.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.5s/it 12.5s
#                    all         73       1152      0.917      0.926      0.966       0.89      0.917      0.926       0.96      0.856
#              1st Molar         63        139      0.912      0.898      0.964      0.877      0.912      0.898      0.964      0.872
#           1st Premolar         73        174        0.9      0.914      0.958      0.887        0.9      0.914      0.958      0.866
#              2nd Molar         51        104      0.929      0.894       0.97       0.88      0.929      0.894      0.966      0.881
#           2nd Premolar         64        150      0.902      0.921       0.95      0.864      0.902      0.921       0.95      0.828
#              3rd Molar          9         13      0.854      0.898      0.933       0.84      0.854      0.898      0.888       0.72
#                 Canine         73        190      0.942      0.963      0.982      0.907      0.942      0.963       0.98      0.885
#        Central Incisor         71        190      0.957      0.974      0.989      0.947      0.957      0.974      0.989      0.913
#        Lateral Incisor         73        192      0.938      0.948      0.984      0.919      0.938      0.948      0.984      0.882
# Speed: 8.3ms preprocess, 26.2ms inference, 0.0ms loss, 7.7ms postprocess per image
# Results saved to /content/runs/segment/val-2
#
# 📊 RESULTADOS EN TEST:
#   mAP@50:     0.9663  (meta: ≥ 0.75)
#   mAP@50-95:  0.8900
#   Precisión:  0.9167   (meta: ≥ 0.80)
#   Recall:     0.9262   (meta: ≥ 0.70)
#
# ✅ META mAP@50 CUMPLIDA

# %% [markdown]
# ## CELL 8 — Inference and Visualization Using Images from Drive

# %%
from IPython.display import Image, display
import glob

test_imgs = [
    '/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/IMAGENES PRUEBA/IMG1.jpeg',
    '/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/IMAGENES PRUEBA/IMG2.jpeg'
]

results_pred = model.predict(
    source=test_imgs,
    save=True,
    project='runs/prueba',
    name='imagenes_prueba_s',
    conf=0.25,
    device='cuda:0'
)

print("🦷 Predicciones del modelo:\n")
pred_imgs = sorted(glob.glob('runs/prueba/imagenes_prueba_s/*'))
for img_path in pred_imgs:
    print(f"📸 {img_path.split('/')[-1]}")
    display(Image(img_path, width=700))
# Out:
# 0: 448x640 2 1st Molars, 2 1st Premolars, 2 2nd Molars, 2 2nd Premolars, 1 3rd Molar, 5 Canines, 4 Central Incisors, 4 Lateral Incisors, 36.8ms
# 1: 448x640 2 1st Molars, 2 1st Premolars, 2 2nd Molars, 2 2nd Premolars, 2 Canines, 2 Central Incisors, 2 Lateral Incisors, 36.8ms
# Speed: 3.6ms preprocess, 36.8ms inference, 11.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/segment/runs/prueba/imagenes_prueba_s
# 🦷 Predicciones del modelo:

# %% [markdown]
# ## CELL 9 — Save best.pt to Drive (YOLO26m-sec)

# %%
import shutil
from pathlib import Path

dst_dir = Path('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/MODELO DIENTES')
dst_dir.mkdir(parents=True, exist_ok=True)

shutil.copy(BEST_MODEL_PATH, dst_dir / 'yolo26s_dientes_best.pt')
shutil.copy(SAVE_DIR / 'confusion_matrix.png', dst_dir / f'confusion_matrix_s.png') \
    if (SAVE_DIR / 'confusion_matrix.png').exists() else None

print("✅ Modelo guardado en Drive:")
print(f"   {dst_dir / 'yolo26s_dientes_best.pt'}")
# Out:
# ✅ Modelo guardado en Drive:
#    /content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/MODELO DIENTES/yolo26s_dientes_best.pt

# %% [markdown]
# ## CELL E — Record results in a comparison table (nano / small / medium)
#
# This cell adds a row to a CSV file shared on Drive, so that once you've finished running the three notebooks (n, s, m), you'll have a single comparison table ready for the article.

# %%
import pandas as pd
from pathlib import Path

comp_path = Path('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_modelos.csv')

n_params = sum(p.numel() for p in model.model.parameters())
size_mb = BEST_MODEL_PATH.stat().st_size / (1024 * 1024)

fila = {
    'modelo': 'YOLO26s-seg',
    'mAP50': round(float(metrics.box.map50), 4),
    'mAP50-95': round(float(metrics.box.map), 4),
    'precision': round(float(metrics.box.mp), 4),
    'recall': round(float(metrics.box.mr), 4),
    'parametros': n_params,
    'tamano_MB': round(size_mb, 2),
    'inferencia_ms': round(metrics.speed.get('inference', 0), 2),
}

if comp_path.exists():
    df_comp = pd.read_csv(comp_path)
    df_comp = df_comp[df_comp['modelo'] != fila['modelo']]  # evita duplicados si se re-corre
    df_comp = pd.concat([df_comp, pd.DataFrame([fila])], ignore_index=True)
else:
    df_comp = pd.DataFrame([fila])

df_comp.to_csv(comp_path, index=False)
print("✅ Fila añadida a la tabla comparativa:")
print(df_comp)

# NOTE: this cell appends/updates a row in a CSV shared across the three variant notebooks (n/s/m); run all three to get the full comparison.
# Out:
# ✅ Fila añadida a la tabla comparativa:
#         modelo   mAP50  mAP50-95  precision  recall  parametros  tamano_MB  \
# 0  YOLO26s-seg  0.9663      0.89     0.9167  0.9262    10368436      22.29
#
#    inferencia_ms
# 0          26.21

# %% [markdown]
# ### (Optional, run only after you have run n + s + m) — Final comparison chart
#
# Run this cell once you have run the 3 notebooks (nano, small, medium): it will read `comparacion_modelos.csv` and generate the comparative bar chart for the article.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_comp = pd.read_csv('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_modelos.csv')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

df_comp.plot(x='modelo', y=['mAP50', 'mAP50-95', 'precision', 'recall'], kind='bar', ax=axes[0])
axes[0].set_title('Métricas de desempeño por variante')
axes[0].set_ylabel('Valor')
axes[0].legend(loc='lower right')
axes[0].tick_params(axis='x', rotation=0)

ax2 = axes[1]
ax2.bar(df_comp['modelo'], df_comp['inferencia_ms'], color='#3b82f6')
ax2.set_ylabel('Tiempo de inferencia (ms)', color='#3b82f6')
ax2b = ax2.twinx()
ax2b.plot(df_comp['modelo'], df_comp['tamano_MB'], color='#ef4444', marker='o')
ax2b.set_ylabel('Tamaño del modelo (MB)', color='#ef4444')
axes[1].set_title('Costo computacional por variante')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_final_modelos.png', dpi=200)
plt.show()

# %% [markdown]
# # Trains YOLO26m-seg from scratch on the tooth instance-segmentation dataset (DATASET DIENTES), with targeted oversampling of the '3rd Molar' minority class. Generates article Table 9 (class distribution), Figure 2 (oversampling effect), Figure 3 (augmentation examples), and contributes one row to the cross-variant comparison table used for Table 10/11.

# %% [markdown]
# ## CELL 1 — Set up the unit and copy the dataset into Colab

# %%
import os, shutil
from pathlib import Path
from google.colab import drive

drive.mount('/content/drive')

src = Path("/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/DATASET DIENTES")
dst = Path("/content/dataset")

if not dst.exists():
    print("Copiando dataset...")
    shutil.copytree(src, dst)
    print("✅ Copia completada")
# Out:
# Mounted at /content/drive
# Copiando dataset...
# ✅ Copia completada

# %% [markdown]
# ## CELL 2 — Verify the dataset

# %%
splits = ['train', 'valid', 'test']
for split in splits:
    imgs = list((dst / split / 'images').glob('*'))
    lbls = list((dst / split / 'labels').glob('*.txt'))
    print(f"{split}: {len(imgs)} imágenes | {len(lbls)} labels")
# Out:
# train: 1650 imágenes | 1750 labels
# valid: 110 imágenes | 110 labels
# test: 73 imágenes | 73 labels

# %% [markdown]
# ## CELL 3 — Identify Classes

# %%
import glob

ids = set()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line in open(f):
        if line.strip():
            ids.add(int(line.split()[0]))

print(f"Total de clases: {len(ids)}")
print(f"IDs encontrados: {sorted(ids)}")
# Out:
# Total de clases: 8
# IDs encontrados: [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ## CELL 4 — Configure data.yaml

# %%
yaml_content = """names:
- 1st Molar
- 1st Premolar
- 2nd Molar
- 2nd Premolar
- 3rd Molar
- Canine
- Central Incisor
- Lateral Incisor
nc: 8
path: /content/dataset
test: test/images
train: train/images
val: valid/images
"""

with open('/content/dataset/data.yaml', 'w') as f:
    f.write(yaml_content)
print("✅ data.yaml actualizado")

names = ['1st Molar', '1st Premolar', '2nd Molar', '2nd Premolar',
         '3rd Molar', 'Canine', 'Central Incisor', 'Lateral Incisor']
# Out:
# ✅ data.yaml actualizado

# %%
from collections import Counter
import glob

labels = glob.glob('/content/dataset/train/labels/*.txt')
counter = Counter()
for f in labels:
    with open(f) as file:
        for line in file:
            class_id = line.split()[0]
            counter[class_id] += 1
print(counter)
# Out:
# Counter({'6': 4603, '7': 4491, '5': 4417, '1': 4093, '0': 3587, '3': 3576, '2': 2775, '4': 491})

# %% [markdown]
# ## CELL 5 — Install the YOLO library

# %%
# ⚠️ After running: Runtime Menu > Restart Session
# !pip install ultralytics albumentations
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.92-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.13.4)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.92-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 32.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.92 ultralytics-thop-2.0.20

# %% [markdown]
# ## CELL 5.5 — Oversampling with augmentation while preserving SEGMENTATION (polygons)
#
# Just like in the nano pipeline: the minority class (3rd Molar) is balanced by generating augmented copies while preserving the polygons.

# %%
import cv2
import numpy as np
import glob, os
import albumentations as A

transform = A.Compose([
    A.Rotate(limit=15, p=0.7),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.6),
    A.Affine(scale=(0.9, 1.1), p=0.5),
    A.GaussNoise(std_range=(0.02, 0.08), p=0.3),
], keypoint_params=A.KeypointParams(format='xy', remove_invisible=False))

labels_con_3er_molar = [f for f in glob.glob('/content/dataset/train/labels/*.txt')
                         if any(line.startswith('4 ') for line in open(f))]

print(f"Imágenes con 3rd Molar: {len(labels_con_3er_molar)}")

N_COPIAS = 5

for label_path in labels_con_3er_molar:
    img_path = label_path.replace('labels', 'images').replace('.txt', '.jpg')
    if not os.path.exists(img_path):
        continue
    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    poligonos = []
    clases = []
    with open(label_path) as f:
        for line_str in f:
            parts = line_str.strip().split()
            if not parts:
                continue
            cls_id = int(parts[0])
            coords = [float(p) for p in parts[1:]]
            puntos_norm = np.array(coords).reshape(-1, 2)
            puntos_px = puntos_norm * [w, h]
            poligonos.append(puntos_px)
            clases.append(cls_id)

    todos_los_puntos = np.vstack(poligonos)
    longitudes = [len(p) for p in poligonos]

    for i in range(N_COPIAS):
        try:
            aug = transform(image=img, keypoints=todos_los_puntos.tolist())
        except Exception as e:
            print(f"⚠️ Error en {img_path}: {e}")
            continue

        img_aug = aug['image']
        kpts_aug = np.array(aug['keypoints'])
        h_new, w_new = img_aug.shape[:2]

        nuevos_poligonos = []
        idx = 0
        for longitud in longitudes:
            poly = kpts_aug[idx:idx+longitud]
            idx += longitud
            poly_norm = poly / [w_new, h_new]
            poly_norm = np.clip(poly_norm, 0, 1)
            nuevos_poligonos.append(poly_norm)

        nuevo_nombre = os.path.basename(img_path).replace('.jpg', f'_aug3M_{i}.jpg')
        nueva_img_path = img_path.replace(os.path.basename(img_path), nuevo_nombre)
        nueva_label_path = nueva_img_path.replace('images', 'labels').replace('.jpg', '.txt')

        cv2.imwrite(nueva_img_path, img_aug)
        with open(nueva_label_path, 'w') as f:
            for cls, poly in zip(clases, nuevos_poligonos):
                coords_str = ' '.join(f"{x:.6f} {y:.6f}" for x, y in poly)
                f.write(f"{cls} {coords_str}\n")

print("✅ Oversampling con segmentación preservada — dataset balanceado listo")

ids = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line_str in open(f):
        if line_str.strip():
            ids[int(line_str.split()[0])] += 1
print(ids)
# Out:
# Imágenes con 3rd Molar: 338
# ✅ Oversampling con segmentación preservada — dataset balanceado listo
# Counter({6: 8308, 7: 8156, 5: 8042, 1: 7368, 0: 6852, 3: 6151, 2: 5975, 4: 2856})

# %% [markdown]
# ## CELL A — Comparative Chart of Class Distribution (for the article)

# %%
import matplotlib.pyplot as plt
from collections import Counter
import glob

conteo_antes = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    if '_aug3M_' in f:
        continue
    for line in open(f):
        if line.strip():
            conteo_antes[int(line.split()[0])] += 1

conteo_despues = Counter()
for f in glob.glob('/content/dataset/train/labels/*.txt'):
    for line in open(f):
        if line.strip():
            conteo_despues[int(line.split()[0])] += 1

x = range(8)
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar([i - 0.2 for i in x], [conteo_antes.get(i, 0) for i in x], width=0.4, label='Antes', color='#94a3b8')
ax.bar([i + 0.2 for i in x], [conteo_despues.get(i, 0) for i in x], width=0.4, label='Después', color='#3b82f6')
ax.set_xticks(x)
ax.set_xticklabels(names, rotation=30, ha='right')
ax.set_ylabel('Número de instancias')
ax.set_title('Distribución de clases antes y después del oversampling')
ax.legend()
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/distribucion_clases.png', dpi=200)
plt.show()

print(f"3rd Molar — Antes: {conteo_antes.get(4,0)} | Después: {conteo_despues.get(4,0)}")
# Out:
# 3rd Molar — Antes: 491 | Después: 2856

# %% [markdown]
# ## CELL B — View original image vs. enlarged versions with masks

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def dibujar_poligonos(img_path, label_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w = img.shape[:2]
    overlay = img.copy()

    colores = {0:(255,99,71), 1:(60,179,113), 2:(65,105,225), 3:(255,215,0),
               4:(255,20,147), 5:(148,0,211), 6:(0,206,209), 7:(255,140,0)}

    with open(label_path) as f:
        for line in f:
            parts = line.split()
            cls = int(parts[0])
            coords = np.array(list(map(float, parts[1:]))).reshape(-1, 2)
            coords[:, 0] *= w
            coords[:, 1] *= h
            pts = coords.astype(np.int32)
            cv2.fillPoly(overlay, [pts], colores.get(cls, (200,200,200)))

    return cv2.addWeighted(img, 0.6, overlay, 0.4, 0)

ejemplo_original = labels_con_3er_molar[0]
img_original_path = ejemplo_original.replace('labels', 'images').replace('.txt', '.jpg')

base_name = os.path.basename(img_original_path).replace('.jpg', '')
versiones_aug = [
    f'/content/dataset/train/images/{base_name}_aug3M_0.jpg',
    f'/content/dataset/train/images/{base_name}_aug3M_1.jpg',
]

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

img_orig = dibujar_poligonos(img_original_path, ejemplo_original)
axes[0].imshow(img_orig)
axes[0].set_title('(a) Imagen original')
axes[0].axis('off')

for i, ruta_aug in enumerate(versiones_aug):
    label_aug = ruta_aug.replace('images', 'labels').replace('.jpg', '.txt')
    if os.path.exists(ruta_aug):
        img_aug = dibujar_poligonos(ruta_aug, label_aug)
        axes[i+1].imshow(img_aug)
        axes[i+1].set_title(f'({chr(98+i)}) Versión aumentada {i+1}')
        axes[i+1].axis('off')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_augmentation.png', dpi=200)
plt.show()

# %% [markdown]
# ## CELL 6 — Training from Scratch | YOLO26m-seg with a Balanced Dataset

# %%
from ultralytics import YOLO

model = YOLO('yolo26m-seg.yaml')

results = model.train(
    data='/content/dataset/data.yaml',
    epochs=150,
    imgsz=640,
    batch=4,
    pretrained=False,
    project='runs/dientes',
    name='yolo26m_dientes',
    patience=30,
    device='cuda:0',

    optimizer='AdamW',
    lr0=0.001,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,

    fliplr=0.5,
    flipud=0.1,
    mosaic=1.0,
    mixup=0.1,
    degrees=10.0,
    translate=0.1,
    scale=0.5,
    shear=2.0,

    cos_lr=True,
    close_mosaic=15,
    val=True,
    verbose=True
)

# Get the actual save directory from the results object (avoids path mismatches between the requested 'name' and Ultralytics' actual save folder).
SAVE_DIR = results.save_dir
BEST_MODEL_PATH = SAVE_DIR / 'weights' / 'best.pt'
print(f"📁 Carpeta de resultados: {SAVE_DIR}")
print(f"🏆 Mejor modelo: {BEST_MODEL_PATH}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=15, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/dataset/data.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.1, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolo26m-seg.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26m_dientes, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=False, profile=False, project=runs/dientes, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/segment/runs/dientes/yolo26m_dientes, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 26.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   8008272  ultralytics.nn.modules.head.Segment26        [8, 32, 256, 1, True, [256, 512, 512]]
# YOLO26m-seg summary: 329 layers, 26,982,544 parameters, 26,982,544 gradients, 131.9 GFLOPs
#
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 103.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2420.3±1748.1 MB/s, size: 672.9 KB)
# train: Scanning /content/dataset/train/labels... 3265 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3265/3265 703.9it/s 4.6s
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 69.5±44.0 MB/s, size: 496.5 KB)
# val: Scanning /content/dataset/valid/labels... 110 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 110/110 162.7it/s 0.7s
# val: New cache created: /content/dataset/valid/labels.cache
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 144 weight(decay=0.0), 164 weight(decay=0.0005), 164 bias(decay=0.0)
# Plotting labels to /content/runs/segment/runs/dientes/yolo26m_dientes/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/segment/runs/dientes/yolo26m_dientes
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/150      4.61G      1.717      3.139      2.594   0.009914      2.836         15        640: 100% ━━━━━━━━━━━━ 817/817 1.8it/s 7:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 1.4s/it 19.8s
#                    all        110       1741      0.504      0.542      0.529      0.394      0.497      0.553      0.528      0.381
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/150      5.52G      1.259      1.953      1.599   0.006712      1.799         34        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.6s
#                    all        110       1741      0.601      0.601      0.641      0.488      0.605      0.608      0.643      0.519
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3/150      5.52G      1.109      1.559      1.306   0.005728      1.354         29        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.9it/s 4.8s
#                    all        110       1741      0.748      0.671      0.773       0.62      0.746      0.672      0.774       0.64
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       4/150      5.52G      1.037      1.408      1.158   0.005286      1.187         17        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.743      0.731      0.791      0.644      0.743      0.731       0.79      0.671
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       5/150      5.52G     0.9727      1.312      1.055   0.004876       1.07         64        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.695      0.736      0.793      0.666      0.695      0.736      0.795      0.689
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       6/150      5.52G     0.9088       1.21     0.9727   0.004509     0.9756         23        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.6s
#                    all        110       1741      0.759      0.762      0.848      0.714      0.758      0.761      0.847       0.74
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       7/150      5.52G     0.8817      1.166     0.9096   0.004372      0.898         18        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.0it/s 4.7s
#                    all        110       1741      0.735      0.806      0.853      0.717      0.733      0.807      0.852      0.731
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       8/150      5.52G     0.8476      1.116      0.856   0.004151     0.8316         42        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.1it/s 4.5s
#                    all        110       1741      0.777      0.794      0.851      0.721      0.777      0.792       0.85      0.742
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       9/150      5.52G     0.8182      1.091      0.823   0.004023     0.8139         16        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.3s
#                    all        110       1741      0.758       0.79      0.846      0.728      0.758      0.789      0.846      0.745
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      10/150      5.52G     0.8115      1.047     0.7875   0.003925     0.7638         16        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.7s
#                    all        110       1741       0.83      0.809      0.902      0.752       0.83       0.81      0.902      0.798
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      11/150      5.52G     0.7881      1.039      0.768    0.00383     0.7538         21        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s
#                    all        110       1741      0.824      0.832      0.896      0.781      0.823      0.832      0.896      0.795
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      12/150      5.52G     0.7708      1.016     0.7379   0.003729      0.712         42        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.7it/s 5.1s
#                    all        110       1741      0.806      0.844      0.904      0.784      0.805      0.844      0.904      0.806
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      13/150      5.52G     0.7473     0.9708     0.7112   0.003602     0.7038         29        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.875      0.783      0.907      0.778      0.876      0.784      0.907      0.793
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      14/150      5.52G     0.7346     0.9773     0.6903   0.003536      0.654         12        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.824      0.835      0.899      0.792      0.825      0.834      0.899      0.796
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      15/150      5.52G     0.7371     0.9899     0.6962   0.003548     0.6891         26        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.7it/s 5.1s
#                    all        110       1741      0.864      0.789      0.895       0.79      0.865       0.79      0.895      0.797
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      16/150      5.52G     0.7031     0.9099     0.6408   0.003383     0.6086         35        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 3.9s
#                    all        110       1741      0.837      0.819      0.902      0.798      0.838      0.819      0.901      0.808
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      17/150      5.52G     0.7134     0.9388     0.6385   0.003422     0.6066         79        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.0it/s 4.6s
#                    all        110       1741      0.902      0.794      0.914      0.814      0.903      0.794      0.914      0.813
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      18/150      5.52G     0.6888     0.9052     0.6174   0.003284     0.5968         11        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.7s
#                    all        110       1741      0.876      0.855      0.921      0.811      0.876      0.855      0.922       0.82
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      19/150      5.52G     0.6997     0.9207      0.624   0.003302     0.5959         59        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        110       1741      0.872      0.845      0.922      0.816      0.873      0.845      0.921      0.814
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      20/150      5.52G     0.6885     0.9232     0.6137   0.003249     0.5978         17        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.3s
#                    all        110       1741      0.915      0.847      0.935      0.831      0.916      0.847      0.935      0.833
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      21/150      5.52G     0.6604     0.8749      0.578   0.003152     0.5506         15        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.894      0.855      0.937      0.836      0.895      0.856      0.938      0.826
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      22/150      5.52G     0.6566     0.8717     0.5698   0.003065      0.548         39        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.917      0.839      0.938       0.84      0.918      0.839      0.938      0.835
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      23/150      5.52G     0.6556     0.8615     0.5702   0.003133     0.5553         11        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.3s
#                    all        110       1741      0.851      0.904      0.944      0.849      0.852      0.905      0.944      0.841
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      24/150      5.52G     0.6472     0.8669     0.5762   0.003026     0.5517          9        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.876      0.847      0.925      0.826      0.877      0.848      0.925      0.826
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      25/150      5.52G     0.6515     0.8581     0.5675    0.00306      0.566         26        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.3s
#                    all        110       1741      0.893      0.865       0.93      0.835      0.892      0.865       0.93      0.841
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      26/150      5.52G     0.6403     0.8479     0.5501   0.002985     0.5479         20        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741       0.91      0.846      0.944      0.852       0.91      0.846      0.943      0.843
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      27/150      5.52G     0.6314     0.8326     0.5432   0.002948     0.5231         28        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.907      0.862      0.938      0.849      0.908      0.862      0.937      0.838
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      28/150      5.52G     0.6337     0.8507     0.5431   0.002972     0.5253         26        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.899      0.879      0.941      0.846      0.899      0.879      0.941      0.842
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      29/150      5.52G     0.6293     0.8203      0.527   0.002931     0.4952         10        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.883      0.897      0.942      0.849      0.883      0.897      0.942      0.847
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      30/150      5.52G     0.6129     0.7919     0.5031   0.002833     0.4729         31        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.0it/s 4.7s
#                    all        110       1741      0.901      0.889      0.951      0.854      0.901       0.89      0.951       0.85
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      31/150      5.52G     0.6221     0.8251     0.5283   0.002885     0.5036         15        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.4s
#                    all        110       1741      0.873      0.876      0.937      0.853      0.873      0.877      0.937       0.84
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      32/150      5.52G     0.6136     0.8172     0.5082   0.002879     0.4822         29        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.4it/s 5.8s
#                    all        110       1741      0.866      0.891      0.933      0.847      0.865       0.89      0.932      0.843
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      33/150      5.52G     0.6059     0.8026      0.495   0.002833     0.4628         19        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.897      0.893      0.948      0.859      0.905      0.884      0.948      0.851
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      34/150      5.52G     0.5952     0.7885     0.4835   0.002739     0.4544         67        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.0it/s 3.5s
#                    all        110       1741      0.934      0.881      0.949      0.861      0.934      0.881      0.949      0.849
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      35/150      5.52G     0.5998     0.8011     0.4969   0.002768     0.4703         22        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.6it/s 5.4s
#                    all        110       1741      0.897      0.885      0.936      0.856      0.897      0.886      0.936      0.839
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      36/150      5.52G     0.5933     0.7807     0.4761    0.00276     0.4465         29        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.8it/s 4.9s
#                    all        110       1741      0.912       0.86       0.93      0.845      0.917      0.858      0.932      0.836
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      37/150      5.52G     0.5855     0.7845     0.4727   0.002751     0.4426         78        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.7s
#                    all        110       1741      0.913      0.871      0.945      0.862      0.913      0.871      0.945       0.85
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      38/150      5.52G      0.584     0.7793     0.4646   0.002676     0.4418         35        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.7s
#                    all        110       1741       0.91      0.881      0.943      0.862       0.91      0.882      0.943      0.848
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      39/150      5.52G     0.5835     0.7674     0.4621   0.002698     0.4419         46        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.7s
#                    all        110       1741      0.925      0.891      0.948      0.868      0.925      0.891      0.948      0.852
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      40/150      5.52G     0.5854       0.78     0.4671   0.002682     0.4412         14        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.3s
#                    all        110       1741      0.915      0.891      0.945      0.864      0.916      0.892      0.944       0.85
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      41/150      5.52G     0.5782     0.7601     0.4537   0.002698     0.4304         44        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.4it/s 5.7s
#                    all        110       1741      0.904      0.888      0.951      0.868      0.905      0.889      0.951      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      42/150      5.52G     0.5715     0.7555     0.4548   0.002647     0.4273         26        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.904      0.918      0.961      0.877      0.905      0.918      0.961      0.866
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      43/150      5.52G     0.5666     0.7521     0.4484   0.002601     0.4268         16        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.2s
#                    all        110       1741      0.942       0.88      0.948      0.868      0.942       0.88      0.948      0.857
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      44/150      5.52G     0.5608     0.7423     0.4415   0.002569      0.426         37        640: 100% ━━━━━━━━━━━━ 817/817 1.8it/s 7:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.897      0.893      0.943      0.863      0.898      0.894      0.944      0.846
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      45/150      5.52G     0.5653     0.7458     0.4369   0.002574     0.3913         10        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.0s
#                    all        110       1741       0.92      0.901      0.951      0.872       0.92      0.901      0.951      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      46/150      5.52G     0.5538     0.7345     0.4287   0.002532     0.4023         51        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:11
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s
#                    all        110       1741      0.912      0.905      0.953      0.872      0.912      0.905      0.952      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      47/150      5.52G     0.5681     0.7723     0.4442   0.002588     0.4151         20        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.4s
#                    all        110       1741      0.909      0.878      0.948      0.868       0.91      0.878      0.948       0.85
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      48/150      5.52G     0.5505     0.7421     0.4245   0.002527     0.3878         80        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.7s
#                    all        110       1741      0.883      0.923      0.942      0.864      0.883      0.922      0.942      0.849
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      49/150      5.52G     0.5481     0.7175     0.4141   0.002499     0.3753         20        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.928      0.884      0.948      0.869      0.927      0.883      0.948      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      50/150      5.52G     0.5516     0.7384      0.418   0.002502      0.378         36        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.913      0.891      0.938      0.865      0.913      0.891      0.938      0.845
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      51/150      5.52G      0.547     0.7279     0.4141   0.002502     0.3772         19        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s
#                    all        110       1741      0.914      0.902      0.953      0.873      0.913      0.902      0.952       0.86
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      52/150      5.52G     0.5504      0.739     0.4215   0.002534     0.4022         32        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.926        0.9      0.962      0.881      0.928      0.901      0.962      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      53/150      5.52G     0.5436     0.7212     0.4213   0.002478     0.3897         39        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.7s
#                    all        110       1741      0.902      0.901      0.952      0.871      0.902      0.902      0.951      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      54/150      5.52G     0.5441     0.7178     0.4111   0.002491     0.3812         31        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.6it/s 5.4s
#                    all        110       1741      0.917      0.897      0.953      0.878      0.918      0.897      0.952      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      55/150      5.52G      0.535     0.7204     0.4048    0.00245     0.3761         15        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.941      0.885      0.949      0.874      0.941      0.885      0.949       0.86
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      56/150      5.52G     0.5297     0.6985     0.3866   0.002393     0.3631         57        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.9it/s 4.9s
#                    all        110       1741       0.92      0.908      0.956      0.881      0.921      0.909      0.957      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      57/150      5.52G     0.5281     0.7017     0.3937   0.002405     0.3587         28        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.888      0.913      0.946      0.872      0.889      0.914      0.947      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      58/150      5.52G     0.5243      0.684     0.3813   0.002395     0.3385          8        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        110       1741      0.933      0.887      0.943      0.868      0.933      0.887      0.942      0.849
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      59/150      5.52G     0.5238     0.6991     0.3862   0.002357     0.3464         50        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.3s
#                    all        110       1741      0.919      0.917      0.962      0.885      0.919      0.918      0.963      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      60/150      5.52G     0.5216     0.6885     0.3733   0.002359     0.3335         16        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.0it/s 3.5s
#                    all        110       1741      0.925      0.888      0.949      0.877      0.925      0.888      0.949      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      61/150      5.52G     0.5178     0.6911     0.3773   0.002329     0.3434         11        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.4it/s 5.8s
#                    all        110       1741      0.895      0.905       0.94      0.869      0.895      0.905       0.94      0.853
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      62/150      5.52G     0.5218     0.6908      0.388   0.002405     0.3587         16        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.0it/s 4.7s
#                    all        110       1741      0.918       0.92      0.955      0.879      0.917      0.919      0.955      0.864
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      63/150      5.52G     0.5127     0.6834     0.3764   0.002336     0.3455          8        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.901      0.915      0.953       0.88      0.901      0.915      0.953      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      64/150      5.52G     0.5174     0.6927     0.3737   0.002353     0.3358         17        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.3it/s 4.2s
#                    all        110       1741      0.941       0.88      0.945       0.87      0.942      0.881      0.944      0.855
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      65/150      5.52G     0.5126     0.6877     0.3692   0.002339     0.3307         15        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.6it/s 5.3s
#                    all        110       1741      0.937       0.89      0.951      0.882      0.937       0.89      0.951      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      66/150      5.52G     0.5105     0.6756     0.3675   0.002309     0.3333         21        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.935      0.907      0.955      0.877      0.935      0.908      0.955      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      67/150      5.52G     0.5084     0.6793     0.3688   0.002301     0.3306         80        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.929      0.892      0.952       0.88      0.929      0.893      0.953      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      68/150      5.52G     0.5131     0.6914     0.3707   0.002319      0.335          7        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.7s
#                    all        110       1741      0.929       0.91      0.964       0.89       0.93      0.911      0.964      0.871
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      69/150      5.52G     0.5126     0.6789     0.3622   0.002329     0.3289         31        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.8it/s 5.1s
#                    all        110       1741      0.928      0.914      0.961       0.89      0.928      0.915      0.961       0.87
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      70/150      5.52G     0.5079     0.6703     0.3559   0.002287      0.317         16        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.6it/s 5.3s
#                    all        110       1741      0.922      0.902      0.951      0.878      0.923      0.903      0.952      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      71/150      5.52G     0.5019     0.6683     0.3593    0.00226      0.324         24        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.2s
#                    all        110       1741      0.927      0.903      0.954      0.885      0.928      0.903      0.954      0.864
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      72/150      5.52G      0.508     0.6792      0.368   0.002277     0.3339         32        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.8s
#                    all        110       1741      0.938      0.906      0.953       0.88       0.94      0.906      0.953      0.865
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      73/150      5.52G     0.5088     0.6829     0.3611   0.002302     0.3285         16        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.923      0.923      0.957      0.886      0.924      0.924      0.958      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      74/150      5.52G     0.4949     0.6511     0.3417   0.002206     0.3032         37        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.951      0.893      0.951      0.881      0.952      0.893      0.951      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      75/150      5.52G     0.5024     0.6714     0.3532   0.002254     0.3128         26        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.945       0.89      0.948      0.876      0.945       0.89      0.948      0.859
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      76/150      5.52G     0.4949     0.6622     0.3445   0.002267     0.3088          9        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.9it/s 4.8s
#                    all        110       1741      0.919      0.918      0.953      0.879      0.919      0.918      0.953      0.865
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      77/150      5.52G     0.4929     0.6542     0.3485   0.002223     0.3131         61        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.958      0.875      0.949      0.879      0.957      0.876      0.949       0.86
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      78/150      5.52G     0.5018     0.6724     0.3527    0.00227      0.311         28        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.922      0.918      0.959      0.887      0.921      0.917      0.958      0.872
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      79/150      5.52G     0.4942     0.6598     0.3453   0.002241     0.3057         21        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.7it/s 5.1s
#                    all        110       1741      0.928       0.91      0.958      0.887      0.928       0.91      0.957      0.866
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      80/150      5.52G     0.4949     0.6626     0.3433    0.00223     0.3074         22        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.5it/s 5.6s
#                    all        110       1741      0.934      0.901      0.951      0.884      0.933      0.902      0.952      0.866
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      81/150      5.52G      0.489     0.6462     0.3343   0.002193      0.287         13        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:56
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.1it/s 4.5s
#                    all        110       1741      0.924      0.907      0.957      0.885      0.927      0.906      0.956      0.866
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      82/150      5.52G     0.4948     0.6663     0.3459   0.002233     0.3025         50        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.8it/s 4.9s
#                    all        110       1741      0.936      0.906      0.953      0.884      0.937      0.907      0.954      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      83/150      5.52G     0.4866     0.6504     0.3298   0.002191      0.291         26        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.938      0.915      0.957      0.887      0.938      0.915      0.956      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      84/150      5.52G      0.483     0.6452     0.3301   0.002161     0.2891         28        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.946      0.901      0.948       0.88      0.946      0.901      0.948       0.86
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      85/150      5.52G     0.4846     0.6489     0.3323   0.002157     0.2969         43        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.4s
#                    all        110       1741      0.927      0.923      0.959      0.889      0.927      0.923      0.959      0.871
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      86/150      5.52G     0.4817     0.6472     0.3263   0.002169     0.2906         46        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.915      0.926      0.959      0.886      0.915      0.926      0.958      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      87/150      5.52G     0.4787     0.6419     0.3296   0.002146     0.2902         43        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.2it/s 4.3s
#                    all        110       1741      0.941      0.893      0.954      0.886      0.941      0.893      0.954      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      88/150      5.52G     0.4802      0.645     0.3277    0.00217     0.2955         35        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 7:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.7it/s 5.1s
#                    all        110       1741      0.923       0.91       0.95      0.879      0.923       0.91       0.95      0.861
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      89/150      5.52G     0.4761     0.6409     0.3224    0.00213     0.2826         57        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        110       1741      0.939      0.893      0.949      0.882       0.94      0.894       0.95      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      90/150      5.52G     0.4759     0.6364     0.3169   0.002129     0.2728         27        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.8s
#                    all        110       1741      0.921      0.916      0.952      0.884      0.922      0.917      0.952      0.864
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      91/150      5.52G      0.475     0.6302     0.3182   0.002129     0.2748         18        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.0it/s 4.7s
#                    all        110       1741      0.951      0.894      0.957       0.89      0.951      0.894      0.957      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      92/150      5.52G     0.4698     0.6241     0.3121    0.00211     0.2688          9        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:57
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.932      0.912      0.953      0.886      0.934      0.909      0.953      0.867
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      93/150      5.52G     0.4694     0.6371     0.3174   0.002091     0.2711         18        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        110       1741      0.949       0.91      0.952      0.887      0.949      0.911      0.952      0.863
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      94/150      5.52G     0.4687     0.6264     0.3152   0.002114      0.278         14        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.4it/s 4.1s
#                    all        110       1741      0.926      0.923      0.955      0.888      0.928      0.922      0.955      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      95/150      5.52G     0.4707     0.6236     0.3131   0.002085     0.2786         16        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.6it/s 5.3s
#                    all        110       1741      0.942      0.907      0.951      0.883      0.943      0.907      0.951      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      96/150      5.52G     0.4669     0.6257     0.3089   0.002073     0.2676         16        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.6s
#                    all        110       1741      0.942        0.9      0.947      0.881      0.942        0.9      0.948      0.862
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      97/150      5.52G     0.4601     0.6158     0.3002   0.002034     0.2601         48        640: 100% ━━━━━━━━━━━━ 817/817 1.9it/s 6:60
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        110       1741      0.939      0.909      0.956       0.89       0.94       0.91      0.956      0.868
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      98/150      5.52G     0.4624     0.6158     0.3003   0.002051     0.2552         41        640: 100% ━━━━━━━━━━━━ 817/817 2.0it/s 6:58
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.7it/s 5.1s
#                    all        110       1741      0.932      0.914      0.953      0.888      0.933      0.915      0.954      0.867
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 68, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 98 epochs completed in 11.729 hours.
# Optimizer stripped from /content/runs/segment/runs/dientes/yolo26m_dientes/weights/last.pt, 54.5MB
# Optimizer stripped from /content/runs/segment/runs/dientes/yolo26m_dientes/weights/best.pt, 54.5MB
#
# Validating /content/runs/segment/runs/dientes/yolo26m_dientes/weights/best.pt...
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m-seg summary (fused): 149 layers, 23,513,636 parameters, 0 gradients, 121.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 1.9it/s 7.3s
#                    all        110       1741      0.929      0.912      0.964       0.89       0.93      0.912      0.964      0.871
#              1st Molar        100        219      0.949      0.941      0.978      0.906      0.949      0.941      0.978      0.904
#           1st Premolar        106        248      0.908       0.94      0.976      0.908      0.912      0.944      0.976      0.892
#              2nd Molar         86        170       0.93      0.945      0.976      0.902       0.93      0.945      0.976      0.899
#           2nd Premolar        102        232      0.937      0.935      0.975        0.9      0.937      0.935      0.972      0.882
#              3rd Molar         13         20      0.827       0.72      0.857      0.746      0.827       0.72      0.857      0.695
#                 Canine        109        282      0.967      0.921      0.981      0.912      0.967      0.921      0.981      0.891
#        Central Incisor        108        287      0.966      0.958      0.988      0.931      0.966      0.958      0.988      0.912
#        Lateral Incisor        109        283      0.946      0.933      0.982      0.917      0.946      0.933      0.981      0.895
# Speed: 0.4ms preprocess, 21.1ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to /content/runs/segment/runs/dientes/yolo26m_dientes
# 📁 Carpeta de resultados: /content/runs/segment/runs/dientes/yolo26m_dientes
# 🏆 Mejor modelo: /content/runs/segment/runs/dientes/yolo26m_dientes/weights/best.pt

# %% [markdown]
# ## CELL C — Training curves (loss, mAP50, precision, recall by epoch)

# %%
import pandas as pd
import matplotlib.pyplot as plt

results_csv = SAVE_DIR / 'results.csv'
df = pd.read_csv(results_csv)
df.columns = df.columns.str.strip()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(df['epoch'], df['train/box_loss'], label='Train box loss')
axes[0].plot(df['epoch'], df['val/box_loss'], label='Val box loss')
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Pérdida')
axes[0].set_title('Curva de pérdida durante el entrenamiento')
axes[0].legend()

axes[1].plot(df['epoch'], df['metrics/mAP50(B)'], label='mAP@50', color='green')
axes[1].plot(df['epoch'], df['metrics/precision(B)'], label='Precisión', color='blue')
axes[1].plot(df['epoch'], df['metrics/recall(B)'], label='Recall', color='orange')
axes[1].axhline(y=0.75, color='red', linestyle='--', label='Meta mAP50 (0.75)')
axes[1].set_xlabel('Época')
axes[1].set_ylabel('Valor')
axes[1].set_title('Métricas de evaluación por época')
axes[1].legend()

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/curvas_entrenamiento_m.png', dpi=200)
plt.show()

# %% [markdown]
# ## CELL D — Metrics by class (table for the article)

# %%
model = YOLO(BEST_MODEL_PATH)
metrics = model.val(data='/content/dataset/data.yaml', split='test')

print("📊 mAP50 por clase:\n")
tabla_resultados = []
for i, name in enumerate(names):
    ap50 = metrics.box.ap50[i] if i < len(metrics.box.ap50) else 0
    tabla_resultados.append({'Clase': name, 'mAP50': f"{ap50:.3f}"})
    print(f"  {name:20s}: {ap50:.3f}")

import pandas as pd
df_resultados = pd.DataFrame(tabla_resultados)
df_resultados.to_csv('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/mAP_por_clase_m.csv', index=False)
print("\n✅ Tabla guardada en Drive para pegar en el artículo")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m-seg summary (fused): 149 layers, 23,513,636 parameters, 0 gradients, 121.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 167.1±85.9 MB/s, size: 909.8 KB)
# val: Scanning /content/dataset/test/labels... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 353.4it/s 0.2s
# val: New cache created: /content/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.5s/it 12.5s
#                    all         73       1152       0.89      0.899      0.946      0.873      0.889      0.899      0.944      0.846
#              1st Molar         63        139      0.861      0.895      0.949      0.866      0.861      0.895      0.949      0.855
#           1st Premolar         73        174      0.918      0.925      0.974      0.897      0.913       0.92      0.965      0.875
#              2nd Molar         51        104       0.91      0.875      0.945      0.867       0.91      0.875      0.945      0.851
#           2nd Premolar         64        150      0.892      0.873       0.96      0.872      0.892      0.873      0.959      0.841
#              3rd Molar          9         13      0.707      0.769      0.781      0.727      0.707      0.769      0.781      0.675
#                 Canine         73        190      0.938      0.949      0.982      0.899      0.938      0.949      0.981      0.883
#        Central Incisor         71        190      0.966      0.963      0.988      0.942      0.966      0.963      0.988      0.909
#        Lateral Incisor         73        192      0.928      0.944      0.986      0.916      0.928      0.944      0.986      0.877
# Speed: 6.6ms preprocess, 45.9ms inference, 0.1ms loss, 8.3ms postprocess per image
# Results saved to /content/runs/segment/val
# 📊 mAP50 por clase:
#
#   1st Molar           : 0.949
#   1st Premolar        : 0.974
#   2nd Molar           : 0.945
#   2nd Premolar        : 0.960
#   3rd Molar           : 0.781
#   Canine              : 0.982
#   Central Incisor     : 0.988
#   Lateral Incisor     : 0.986
#
# ✅ Tabla guardada en Drive para pegar en el artículo

# %% [markdown]
# ## CELL 7 — Final evaluation of the test set

# %%
metrics = model.val(
    data='/content/dataset/data.yaml',
    split='test'
)

print("\n📊 RESULTADOS EN TEST:")
print(f"  mAP@50:     {metrics.box.map50:.4f}  (meta: ≥ 0.75)")
print(f"  mAP@50-95:  {metrics.box.map:.4f}")
print(f"  Precisión:  {metrics.box.mp:.4f}   (meta: ≥ 0.80)")
print(f"  Recall:     {metrics.box.mr:.4f}   (meta: ≥ 0.70)")

if metrics.box.map50 >= 0.75:
    print("\n✅ META mAP@50 CUMPLIDA")
else:
    print(f"\n⚠️ mAP@50 = {metrics.box.map50:.4f} — debajo de la meta")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2606.0±1160.3 MB/s, size: 1284.5 KB)
# val: Scanning /content/dataset/test/labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 73/73 21.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1s/it 10.5s
#                    all         73       1152       0.89      0.899      0.946      0.873      0.889      0.899      0.944      0.846
#              1st Molar         63        139      0.861      0.895      0.949      0.866      0.861      0.895      0.949      0.855
#           1st Premolar         73        174      0.918      0.925      0.974      0.897      0.913       0.92      0.965      0.875
#              2nd Molar         51        104       0.91      0.875      0.945      0.867       0.91      0.875      0.945      0.851
#           2nd Premolar         64        150      0.892      0.873       0.96      0.872      0.892      0.873      0.959      0.841
#              3rd Molar          9         13      0.707      0.769      0.781      0.727      0.707      0.769      0.781      0.675
#                 Canine         73        190      0.938      0.949      0.982      0.899      0.938      0.949      0.981      0.883
#        Central Incisor         71        190      0.966      0.963      0.988      0.942      0.966      0.963      0.988      0.909
#        Lateral Incisor         73        192      0.928      0.944      0.986      0.916      0.928      0.944      0.986      0.877
# Speed: 5.2ms preprocess, 33.9ms inference, 0.0ms loss, 5.3ms postprocess per image
# Results saved to /content/runs/segment/val-2
#
# 📊 RESULTADOS EN TEST:
#   mAP@50:     0.9458  (meta: ≥ 0.75)
#   mAP@50-95:  0.8732
#   Precisión:  0.8901   (meta: ≥ 0.80)
#   Recall:     0.8992   (meta: ≥ 0.70)
#
# ✅ META mAP@50 CUMPLIDA

# %% [markdown]
# ## CELL 8 — Inference and Visualization Using Images from Drive

# %%
from IPython.display import Image, display
import glob

test_imgs = [
    '/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/IMAGENES PRUEBA/IMG1.jpeg',
    '/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/IMAGENES PRUEBA/IMG2.jpeg'
]

results_pred = model.predict(
    source=test_imgs,
    save=True,
    project='runs/prueba',
    name='imagenes_prueba_m',
    conf=0.25,
    device='cuda:0'
)

print("🦷 Predicciones del modelo:\n")
pred_imgs = sorted(glob.glob('runs/prueba/imagenes_prueba_m/*'))
for img_path in pred_imgs:
    print(f"📸 {img_path.split('/')[-1]}")
    display(Image(img_path, width=700))

# %% [markdown]
# ## CELL 9 — Save best.pt to Drive (YOLO26m-sec)

# %%
import shutil
from pathlib import Path

dst_dir = Path('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/MODELO DIENTES')
dst_dir.mkdir(parents=True, exist_ok=True)

shutil.copy(BEST_MODEL_PATH, dst_dir / 'yolo26m_dientes_best.pt')
shutil.copy(SAVE_DIR / 'confusion_matrix.png', dst_dir / f'confusion_matrix_m.png') \
    if (SAVE_DIR / 'confusion_matrix.png').exists() else None

print("✅ Modelo guardado en Drive:")
print(f"   {dst_dir / 'yolo26m_dientes_best.pt'}")
# Out:
# ✅ Modelo guardado en Drive:
#    /content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/MODELO DIENTES/yolo26m_dientes_best.pt

# %% [markdown]
# ## CELL E — Record results in a comparison table (nano / small / medium)
#
# This cell adds a row to a CSV file shared on Drive, so that once you've finished running the three notebooks (n, s, m), you'll have a single comparison table ready for the article.

# %%
import pandas as pd
from pathlib import Path

comp_path = Path('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_modelos.csv')

n_params = sum(p.numel() for p in model.model.parameters())
size_mb = BEST_MODEL_PATH.stat().st_size / (1024 * 1024)

fila = {
    'modelo': 'YOLO26m-seg',
    'mAP50': round(float(metrics.box.map50), 4),
    'mAP50-95': round(float(metrics.box.map), 4),
    'precision': round(float(metrics.box.mp), 4),
    'recall': round(float(metrics.box.mr), 4),
    'parametros': n_params,
    'tamano_MB': round(size_mb, 2),
    'inferencia_ms': round(metrics.speed.get('inference', 0), 2),
}

if comp_path.exists():
    df_comp = pd.read_csv(comp_path)
    df_comp = df_comp[df_comp['modelo'] != fila['modelo']]  # evita duplicados si se re-corre
    df_comp = pd.concat([df_comp, pd.DataFrame([fila])], ignore_index=True)
else:
    df_comp = pd.DataFrame([fila])

df_comp.to_csv(comp_path, index=False)
print("✅ Fila añadida a la tabla comparativa:")
print(df_comp)

# NOTE: this cell appends/updates a row in a CSV shared across the three variant notebooks (n/s/m); run all three to get the full comparison.
# Out:
# ✅ Fila añadida a la tabla comparativa:
#         modelo   mAP50  mAP50-95  precision  recall  parametros  tamano_MB  \
# 0  YOLO26s-seg  0.9663    0.8900     0.9167  0.9262    10368436      22.29
# 1  YOLO26n-seg  0.9523    0.8556     0.9115  0.8881     2690444       6.26
# 2  YOLO26m-seg  0.9458    0.8732     0.8901  0.8992    23513636      51.98
#
#    inferencia_ms
# 0          26.21
# 1          14.92
# 2          33.93

# %% [markdown]
# ### (Optional, run only after you have run n + s + m) — Final comparison chart
#
# Run this cell once you have run the 3 notebooks (nano, small, medium): it will read `comparacion_modelos.csv` and generate the comparative bar chart for the article.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_comp = pd.read_csv('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_modelos.csv')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

df_comp.plot(x='modelo', y=['mAP50', 'mAP50-95', 'precision', 'recall'], kind='bar', ax=axes[0])
axes[0].set_title('Métricas de desempeño por variante')
axes[0].set_ylabel('Valor')
axes[0].legend(loc='lower right')
axes[0].tick_params(axis='x', rotation=0)

ax2 = axes[1]
ax2.bar(df_comp['modelo'], df_comp['inferencia_ms'], color='#3b82f6')
ax2.set_ylabel('Tiempo de inferencia (ms)', color='#3b82f6')
ax2b = ax2.twinx()
ax2b.plot(df_comp['modelo'], df_comp['tamano_MB'], color='#ef4444', marker='o')
ax2b.set_ylabel('Tamaño del modelo (MB)', color='#ef4444')
axes[1].set_title('Costo computacional por variante')

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/UNIVERSIDAD/9NO SEMESTRE/TITULACION/comparacion_final_modelos.png', dpi=200)
plt.show()
